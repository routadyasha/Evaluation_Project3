# %% [markdown]
# # Zomato Restaurant
#
# ## Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
# • Country code
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
#
# Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %% [markdown]
# Importing The required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the required dataset

# %%
df1=pd.read_csv("zomato.csv")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df2=pd.read_csv('country_code.csv')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=pd.merge(df1,df2)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### Target Variable

# %%
df['Average Cost for two']
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9551, dtype: int64

# %% [markdown]
# The target variable contains continuous numerical values so its a regression problem.

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
df.sample(10)
# Out:
#       Restaurant ID          Restaurant Name  Country Code       City  \
# 3862       18431175        Urban Patty House             1  New Delhi
# 1103       18477428               Yummy Cake             1  Faridabad
# 8831       18432196                   Shri G             1      Noida
# 7594       18037792  Manpasand Punjabi Zaika             1  New Delhi
# 4321       18357911          Tourist Janpath             1  New Delhi
# 6893         308992   Kumaon Dhaba & Service             1  New Delhi
# 5980         308991          Gelato Italiano             1  New Delhi
# 2571       18433900                  Chateau             1  New Delhi
# 2591           7584           Bikaner Sweets             1  New Delhi
# 5038       18356811               Hungry Hut             1  New Delhi
#
#                                                 Address  \
# 3862  Shop 13, DDA Market, Hudson Lane, GTB Nagar, N...
# 1103  285, DDA Flat, Suraj Kund Road, Pul Prahladpur...
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# The dataset has 9551 rows and 22 columns.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# The dataset has int64, object and float64 type of data

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Key Observations
#
# The dataset has no null values present in it

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Key Observations
#
# The dataset has no nan values present in it

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes',
#  'Country']

# %%
df['Restaurant ID'].nunique()
# Out:
# 9542

# %% [markdown]
# Key Observations
#
# The step column has 9551 unique values

# %%
df['Restaurant Name'].nunique()
# Out:
# 7437

# %% [markdown]
# Key Observations
#
# The type column has 5 unique values and its of object data type

# %%
df['Country Code'].nunique()
# Out:
# 15

# %% [markdown]
# Key Observations
#
# The amount column has 5316900 unique values and its of float64 data type

# %%
df['City'].nunique()
# Out:
# 140

# %% [markdown]
# Key Observations
#
# The nameOrig column has 6353307 unique values and its of object data type

# %%
df['Address'].nunique()
# Out:
# 8910

# %% [markdown]
# Key Observations
#
# The oldbalanceOrg column has 1845844 unique values and its of float64 data type

# %%
df['Locality'].nunique()
# Out:
# 1206

# %% [markdown]
# Key Observations
#
# The newbalanceOrig column has 2682586 unique values and its of float64 data type

# %%
df['Locality Verbose'].nunique()
# Out:
# 1263

# %% [markdown]
# Key Observations
#
# The isFraud column has 2 unique values and its of int64 data type

# %%
df['Longitude'].nunique()
# Out:
# 8111

# %%
df['Latitude'].nunique()
# Out:
# 8668

# %% [markdown]
# Key Observations
#
# The isFlaggedFraud column has 2 unique values and its of int64 data type

# %%
df['Latitude'].nunique()
# Out:
# 8668

# %%
df['Cuisines'].nunique()
# Out:
# 1825

# %% [markdown]
# Key Observations
#
# The oldbalanceDest column has 3614697 unique values and its of float64 data type

# %%
df['Average Cost for two'].nunique()
# Out:
# 140

# %% [markdown]
# Key Observations
#
# The newbalanceDest column has 3555499 unique values and its of float64 data type

# %%
df['Currency'].nunique()
# Out:
# 12

# %%
df['Has Table booking'].nunique()
# Out:
# 2

# %%
df['Has Online delivery'].nunique()
# Out:
# 2

# %%
df['Switch to order menu'].nunique()
# Out:
# 1

# %%
df['Price range'].nunique()
# Out:
# 4

# %%
df['Aggregate rating'].nunique()
# Out:
# 33

# %%
df['Rating color'].nunique()
# Out:
# 6

# %%
df['Rating text'].nunique()
# Out:
# 6

# %%
df['Votes'].nunique()
# Out:
# 1012

# %%
df['Country'].nunique()
# Out:
# 15

# %% [markdown]
# Key Observations
#
# The nameDest column has 2722362 unique values and its of object data type

# %%
df.nunique().to_frame('No of unique values')
# Out:
#                       No of unique values
# Restaurant ID                        9542
# Restaurant Name                      7437
# Country Code                           15
# City                                  140
# Address                              8910
# Locality                             1206
# Locality Verbose                     1263
# Longitude                            8111
# Latitude                             8668
# Cuisines                             1825
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# Votes                                1012
# ...

# %% [markdown]
# Key Observations
#
# All the unique value counts of each column has been listed in a table

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# Key Observations
#
# 1. The count of each column is equal which indicates there is no missing or null value present and its a balanced dataset
#
# 2. The mean of 'Country Code','Average Cost for two' and 'Votes' column is higher than the 50% (median) of that column indicating the columns are right skewed.
#
# 3. The mean of 'Longitude','Latitude','Price range','Aggregate rating' column is lower than the 50% (median) of that column indicating the columns are left skewed.
#
# 4. The standard deviation of 'Country Code','Longitude','Average Cost for two' and 'Votes' column is very high indicating the dataset is highly spreaded.
#
# 5. The difference between 75% and max value in 'Country Code','Longitude','Latitude','Average Cost for two' and 'Votes' is very high indicatng the presence of outliers

# %% [markdown]
# ### Univariate Analysis

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.histplot(df['Restaurant ID'])
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Count'>

# %%
sns.histplot(df['Restaurant Name'])
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Count'>

# %%
sns.histplot(df['Country Code'])
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Count'>

# %%
sns.histplot(df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
sns.histplot(df['Address'])
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Count'>

# %%
sns.histplot(df['Locality'])
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Count'>

# %%
sns.histplot(df['Locality Verbose'])
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Count'>

# %%
sns.histplot(df['Longitude'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Count'>

# %%
sns.histplot(df['Latitude'])
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Count'>

# %%
sns.histplot(df['Cuisines'])
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Count'>

# %%
sns.histplot(df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Count'>

# %%
sns.histplot(df['Currency'])
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Count'>

# %%
sns.histplot(df['Has Table booking'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Count'>

# %%
sns.stripplot(df['Has Online delivery'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery'>

# %%
sns.stripplot(df['Is delivering now'])
# Out:
# <AxesSubplot:xlabel='Is delivering now'>

# %%
sns.countplot(df['Switch to order menu'])
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='count'>

# %%
sns.countplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %%
sns.countplot(df['Aggregate rating'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %%
sns.countplot(df['Rating color'])
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
sns.countplot(df['Rating text'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %%
sns.countplot(df['Votes'])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='count'>

# %%
sns.countplot(df['Country'])
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
sns.countplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.catplot(x='Has Table booking',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Cuisines',y='Average Cost for two',data=df,kind='bar')

# %% [markdown]
# Key Observations
#
# From the above analysis we conclude that people who transers money instead of withdrawing cash has a higher chance of being fraud

# %%
sns.catplot(x='Has Online delivery',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Is delivering now',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Switch to order menu',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Price range',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Aggregate rating',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Rating color',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(y='Average Cost for two',x='Rating text',data=df,kind='bar')

# %%
sns.catplot(x='Votes',y='Average Cost for two',data=df,kind='bar')

# %%
sns.catplot(x='Country',y='Average Cost for two',data=df,kind='bar')

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %%
corr=df.corr()
corr
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.146270  -0.224362 -0.052626
# Country Code               0.146270      1.000000  -0.694629  0.018049
# Longitude                 -0.224362     -0.694629   1.000000  0.045415
# Latitude                  -0.052626      0.018049   0.045415  1.000000
# Average Cost for two      -0.001629      0.043717   0.045948 -0.111080
# Price range               -0.134528      0.245363  -0.080257 -0.166735
# Aggregate rating          -0.327160      0.281295  -0.114733  0.000197
# Votes                     -0.147434      0.154361  -0.084371 -0.022914
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001629    -0.134528         -0.327160
# Country Code                      0.043717     0.245363          0.281295
# Longitude                         0.045948    -0.080257         -0.114733
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,cmap='Greens',annot=True)
plt.title("Correlation Heatmap")
plt.xlabel("Features")
plt.ylabel("Features")
plt.show()

# %% [markdown]
# Key Observations
#
# From the above analysis we observe that all the columns except 'Restaurant ID' and 'Latitude' columns are positively correlated with target variable.
# 'Aggregate rating' and 'Price Range' columns are positively correlated with each other.

# %% [markdown]
# ### Plotting Outliers

# %%
plt.figure(figsize=(12, 6))
df.plot(kind='box',subplots=True,layout=(2, 5))
plt.suptitle("Box Plots of DataFrame Columns")
plt.tight_layout()
plt.show()

# %% [markdown]
# Key Observations
#
# We can observe that all the variable except Restaurant ID and Price range variable has outliers present in them.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
plt.boxplot(df['Restaurant ID'])
plt.suptitle("Restaurant ID")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Country Code'])
plt.suptitle("Box Plots of Country Code")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Longitude'])
plt.suptitle("Box Plots of Longitude")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Latitude'])
plt.suptitle("Box Plots of Latitude")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Price range'])
plt.suptitle("Box Plots of Price range")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Aggregate rating'])
plt.suptitle("Box Plots of Aggregate rating")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Votes'])
plt.suptitle("Box Plots of Votes")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separating Numerical and Categorical Columns

# %%
numeric_columns = df.select_dtypes(include=[np.number])

# %%
numeric_columns
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 0                     1100            3               4.8    314
# 1                     1200            3               4.5    591
# 2                     4000            4               4.4    270
# ...

# %%
cat_col=df.select_dtypes(exclude=[np.number])

# %%
cat_col
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546               Naml۱ Gurme         ��stanbul
# 9547              Ceviz A��ac۱         ��stanbul
# 9548                     Huqqa         ��stanbul
# 9549               A���k Kahve         ��stanbul
# 9550  Walter's Coffee Roastery         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...

# %% [markdown]
# ### Checking Skewness

# %%
df.skew()
# Out:
# Restaurant ID            0.063496
# Country Code             3.064922
# Longitude               -2.819828
# Latitude                -3.081780
# Average Cost for two    35.461264
# Price range              0.889879
# Aggregate rating        -0.953052
# Votes                    8.813270
# dtype: float64

# %% [markdown]
# Key Observations
#
# all the numerical columns are highly skewed but we wont remove skewness from target variable isFraud

# %%
plt.figure(figsize=(10,8))
plotnumber=1
for i in numeric_columns.columns:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(numeric_columns[i],color='m')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
sns.distplot(df['Restaurant ID'])
plt.show()

# %%
sns.distplot(df['Country Code'])
plt.show()

# %%
sns.distplot(df['Longitude'])
plt.show()

# %%
sns.distplot(df['Latitude'])
plt.show()

# %%
sns.distplot(df['Average Cost for two'])
plt.show()

# %%
sns.distplot(df['Price range'])
plt.show()

# %%
sns.distplot(df['Aggregate rating'])
plt.show()

# %%
sns.distplot(df['Votes'])
plt.show()

# %% [markdown]
# ## Separating Lables and Features

# %%
x=numeric_columns.drop('Average Cost for two',axis=1)
y=numeric_columns['Average Cost for two']

# %%
x
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  Price range  \
# 0           6317637           162  121.027535  14.565443            3
# 1           6304287           162  121.014101  14.553708            3
# 2           6300002           162  121.056831  14.581404            4
# 3           6318506           162  121.056475  14.585318            4
# 4           6314302           162  121.057508  14.584450            4
# ...             ...           ...         ...        ...          ...
# 9546        5915730           208   28.977392  41.022793            3
# 9547        5908749           208   29.041297  41.009847            3
# 9548        5915807           208   29.034640  41.055817            4
# 9549        5916112           208   29.036019  41.057979            4
# 9550        5927402           208   29.026016  40.984776            2
#
#       Aggregate rating  Votes
# 0                  4.8    314
# 1                  4.5    591
# 2                  4.4    270
# ...

# %%
y
# Out:
# 0       1100
# 1       1200
# 2       4000
# 3       1500
# 4       1500
#         ...
# 9546      80
# 9547     105
# 9548     170
# 9549     120
# 9550      55
# Name: Average Cost for two, Length: 9542, dtype: int64

# %%
x.shape
# Out:
# (9542, 7)

# %%
y.shape
# Out:
# (9542,)

# %%
x.dtypes
# Out:
# Restaurant ID         int64
# Country Code          int64
# Longitude           float64
# Latitude            float64
# Price range           int64
# Aggregate rating    float64
# Votes                 int64
# dtype: object

# %%
y.dtypes
# Out:
# dtype('int64')

# %%
y.value_counts()
# Out:
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: Average Cost for two, Length: 140, dtype: int64

# %% [markdown]
# We dont remove outliers and skewness from target variable so we 1st separated feateres and labels and then we will proceed with outliers and skewness removal fron feature dataset i.e. X

# %% [markdown]
# ## Removing Outliers

# %%
x.shape
# Out:
# (9542, 7)

# %%
#removing the outliers by Z-Score method
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Price range  \
# 0          0.310034      2.547817   1.377641  1.024849     1.319726
# 1          0.311552      2.547817   1.377315  1.025915     1.319726
# 2          0.312040      2.547817   1.378352  1.023399     2.424069
# 3          0.309935      2.547817   1.378344  1.023043     2.424069
# 4          0.310413      2.547817   1.378369  1.023122     2.424069
# ...             ...           ...        ...       ...          ...
# 9546       0.355749      3.362717   0.856833  1.378286     1.319726
# 9547       0.356543      3.362717   0.855281  1.377110     1.319726
# 9548       0.355740      3.362717   0.855443  1.381285     2.424069
# 9549       0.355706      3.362717   0.855410  1.381482     2.424069
# 9550       0.354421      3.362717   0.855652  1.374833     0.215383
#
#       Aggregate rating     Votes
# 0             1.407683  0.365493
# 1             1.209860  1.009408
# 2             1.143919  0.263210
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  22,   23,   24, ..., 9539, 9540, 9541], dtype=int64), array([3, 3, 3, ..., 1, 1, 1], dtype=int64))

# %%
x_new=x[(z<3).all(axis=1)]
x_new
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  Price range  \
# 0           6317637           162  121.027535  14.565443            3
# 1           6304287           162  121.014101  14.553708            3
# 2           6300002           162  121.056831  14.581404            4
# 3           6318506           162  121.056475  14.585318            4
# 4           6314302           162  121.057508  14.584450            4
# ...             ...           ...         ...        ...          ...
# 9432        6201972           166   51.526653  25.323261            4
# 9433        6201130           166   51.530127  25.350325            4
# 9434       18261203           166   51.512909  25.276180            4
# 9435        6201360           166   51.544576  25.273020            4
# 9436       18318801           166   51.546714  25.283011            4
#
#       Aggregate rating  Votes
# 0                  4.8    314
# 1                  4.5    591
# 2                  4.4    270
# ...

# %%
x_new.shape
# Out:
# (8581, 7)

# %% [markdown]
# Initially we had 9542 rows and now we have 8581 rows so 961 rows are deleted as outliers

# %% [markdown]
# ## Removing Skewness

# %%
x_new.skew()
# Out:
# Restaurant ID        0.116431
# Country Code        10.805559
# Longitude           -3.496889
# Latitude            -3.149880
# Price range          1.022024
# Aggregate rating    -0.878228
# Votes                3.627893
# dtype: float64

# %%
from scipy.stats import skew,boxcox
from scipy import stats
def skee(a):
    model=[np.sqrt(a),np.log(a),stats.boxcox(a)[0]]
    print('Original skewness was: ',a.skew())
    print('\n')
    for m in model:
        x=m
        print(skew(m))
        print('\n')

# %%
skee(x_new['Country Code'])
# Out:
# Original skewness was:  10.805558577247917
#
#
# 10.483210665013383
#
#
# 10.313113005063077
#
#
# 10.277623514016616

# %%
skee(x_new['Price range'])
# Out:
# Original skewness was:  1.0220239806845568
#
#
# 0.7002911294423456
#
#
# 0.4513978238111577
#
#
# 0.2035186222978462

# %%
skee(x_new['Votes'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35200\3014051945.py in <module>
# ----> 1 skee(x_new['Votes'])
#
# ~\AppData\Local\Temp\ipykernel_35200\3985874679.py in skee(a)
#       2 from scipy import stats
#       3 def skee(a):
# ----> 4     model=[np.sqrt(a),np.log(a),stats.boxcox(a)[0]]
#       5     print('Original skewness was: ',a.skew())
#       6     print('\n')
#
# ~\anaconda3\lib\site-packages\scipy\stats\_morestats.py in boxcox(x, lmbda, alpha, optimizer)
#    1088
#    1089     if np.any(x <= 0):
# -> 1090         raise ValueError("Data must be positive.")
#    1091
#    1092     # If lmbda=None, find the lmbda that maximizes the log-likelihood function.
#
# ValueError: Data must be positive.

# %%
x_new['Votes'] = np.cbrt(x_new['Votes'])

# %%
x_new['Price range'] = stats.boxcox(x_new['Price range'])[0]

# %%
x_new['Country Code'] = np.cbrt(x_new['Country Code'])

# %%
x_new.skew()
# Out:
# Restaurant ID        0.116431
# Country Code        10.407321
# Longitude           -3.496889
# Latitude            -3.149880
# Price range          0.203554
# Aggregate rating    -0.878228
# Votes                0.761670
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
x_new.plot(kind='box',subplots=True,layout=(2, 5))
plt.suptitle("Box Plots of DataFrame Columns")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
plotnumber=1
for i in numeric_columns.columns:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(numeric_columns[i],color='m')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
cat_col.select_dtypes(include=['object']).columns
label_encoders = {}
for col in cat_col:
    le = LabelEncoder()
    cat_col[col] = le.fit_transform(cat_col[col])
    label_encoders[col] = le

# %%
cat_col.shape
# Out:
# (9542, 14)

# %% [markdown]
# ### CONCATINATING FEATURE x_new and cat_col but before that reshaping

# %%
cat_col=cat_col[:len(x_new)]

# %%
cat_col.shape
# Out:
# (8581, 14)

# %%
X=pd.merge(x_new,cat_col,left_index=True, right_index=True)

# %%
X
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  Price range  \
# 0           6317637      5.451362  121.027535  14.565443     0.734806
# 1           6304287      5.451362  121.014101  14.553708     0.734806
# 2           6300002      5.451362  121.056831  14.581404     0.843003
# 3           6318506      5.451362  121.056475  14.585318     0.843003
# 4           6314302      5.451362  121.057508  14.584450     0.843003
# ...             ...           ...         ...        ...          ...
# 8585       18472655      1.000000   77.340435  28.565446     0.000000
# 8586       18279437      1.000000   77.340359  28.565417     0.000000
# 8587       18204489      1.000000   77.340025  28.565491     0.533943
# 8588       18275704      1.000000   77.375657  28.529984     0.000000
# 8589       18332077      1.000000   77.340835  28.566196     0.000000
#
#       Aggregate rating     Votes  Restaurant Name  City  Address  ...  \
# ...

# %%
X.shape
# Out:
# (7864, 21)

# %%
y.shape
# Out:
# (9542,)

# %%
y=y[:len(X)]

# %%
y.shape
# Out:
# (7864,)

# %% [markdown]
# Key Observations
#
# So now we can see that the feature and traget has equal shape.

# %% [markdown]
# ## Dealing with class imbalance

# %% [markdown]
# ### Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
X
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Price range  \
# 0         -0.259860     13.304059   2.723627 -1.769517     1.370281
# 1         -0.261346     13.304059   2.722859 -1.771242     1.370281
# 2         -0.261823     13.304059   2.725301 -1.767171     1.712461
# 3         -0.259763     13.304059   2.725281 -1.766596     1.712461
# 4         -0.260231     13.304059   2.725340 -1.766723     1.712461
# ...             ...           ...        ...       ...          ...
# 7859       1.093043     -0.073252   0.226495  0.288592    -0.953594
# 7860       1.071538     -0.073252   0.226491  0.288587    -0.953594
# 7861       1.063196     -0.073252   0.226472  0.288598     0.735039
# 7862       1.071122     -0.073252   0.228508  0.283378    -0.953594
# 7863       1.077397     -0.073252   0.226518  0.288702    -0.953594
#
#       Aggregate rating     Votes  Restaurant Name      City   Address  ...  \
# ...

# %% [markdown]
# Here in fit method we are giving the data onthe method and the method will do diffenent analysis, it will find out relationship pattern and then we are using transform methos which will on the basis of previous learning the data will be changed
#
# We have scaled the data using Standard Scalarization method to overcome the issue of biasness

# %% [markdown]
# ## Checking Variance Inflation Factor(VIF)

# %% [markdown]
# VIF is used to check multi corlinearility in each column
#
# If in any feature the vif value is above 10 then drop the column, and if 2 or more tahn two features have the vif value more than 10 then the drop the feature that has highest vif value

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X.values,i)
                    for i in range(len(X.columns))]
vif['Features']=X.columns

vif
# Out:
#     VIF values              Features
# 0     1.444068         Restaurant ID
# 1          inf          Country Code
# 2    10.861172             Longitude
# 3    11.275976              Latitude
# 4     1.755681           Price range
# 5     3.447723      Aggregate rating
# 6     4.007778                 Votes
# 7     1.007957       Restaurant Name
# 8     1.205395                  City
# 9     1.061336               Address
# 10  912.811815              Locality
# 11  913.149896      Locality Verbose
# 12    1.033027              Cuisines
# 13         inf              Currency
# 14    1.441347     Has Table booking
# 15    1.243897   Has Online delivery
# 16    1.015587     Is delivering now
# 17         NaN  Switch to order menu
# 18    1.251476          Rating color
# 19    1.653899           Rating text
# 20         inf               Country

# %% [markdown]
# Key Observations
#
# 1. "Restaurant ID",'Price range','Aggregate rating','Votes','Restaurant Name','City','Address','Cuisines','Has Table booking','Has Online delivery','Is delivering now','Rating color','Rating text' has a VIF of min 1.44 to max 4.00, indicating a relatively low level of multicollinearity.
# 2. "Country Code","Country" and "Currency" have VIF values of infinity (inf). This suggests perfect multicollinearity, indicating that these variables are redundant and should be removed from the model.
# 3. "Longitude" and "Latitude" have VIF values of 10.86 and 11.28, respectively, indicating a moderate level of multicollinearity. Consider exploring whether these variables are necessary or if they can be transformed or combined.

# %%
data = X.drop(['Country Code', 'Currency', 'Longitude', 'Latitude'], axis=1,inplace =True)

# %%
data1 = X.drop(['Locality', 'Locality Verbose'], axis=1,inplace =True)

# %%
vif = pd.DataFrame()
vif["Features"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif)
# Out:
#                 Features       VIF
# 0          Restaurant ID  1.427197
# 1            Price range  1.740067
# 2       Aggregate rating  3.441538
# 3                  Votes  3.853671
# 4        Restaurant Name  1.007163
# 5                   City  1.109412
# 6                Address  1.041505
# 7               Cuisines  1.031552
# 8      Has Table booking  1.408880
# 9    Has Online delivery  1.205953
# 10     Is delivering now  1.014910
# 11  Switch to order menu       NaN
# 12          Rating color  1.230969
# 13           Rating text  1.630173
# 14               Country  1.057782

# %%
X['Switch to order menu'].nunique()
# Out:
# 1

# %% [markdown]
# Since the column has a single unique value, it does not provide any useful information for regression problem. In this case, so we can consider dropping the column

# %%
X.drop('Switch to order menu', axis=1, inplace=True)

# %%
print(X.shape)
# Out:
# (7864, 14)

# %% [markdown]
# ### Spliting the data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=43)

# %%
x_train.shape
# Out:
# (5504, 14)

# %%
x_test.shape
# Out:
# (2360, 14)

# %%
y_train.shape
# Out:
# (5504,)

# %%
y_test.shape
# Out:
# (2360,)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Finding the best random state

# %% [markdown]
# Since it a large dataset iterating millions of datas in a loop will take forever to give a result so i took fixed random state 42, to get the best accuracy

# %%
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.linear_model import LinearRegression, SGDRegressor,Ridge, Lasso
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
maxAccu=0
ln=LinearRegression()
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=i)
    mod=ln
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('the best accuracy is ',maxAccu,'on random state',maxRS)
# Out:
# the best accuracy is  0.033694649381766584 on random state 163

# %% [markdown]
# ## Building The Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
lr=LinearRegression()
RFR=RandomForestRegressor()
knn=KNeighborsRegressor()
gbr=GradientBoostingRegressor()
sv=SVR()
dtc=DecisionTreeRegressor()

# %%
print(lr)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# LinearRegression()
#
#
# Mean Squared Error: 309941.0076697608
# R-squared score: 0.03614636537550653

# %%
print(knn)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# KNeighborsRegressor()
#
#
# Mean Squared Error: 380610.2704386523
# R-squared score: -0.18362070026107813

# %%
print(RFR)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# RandomForestRegressor()
#
#
# Mean Squared Error: 326088.34484990465
# R-squared score: -0.014068576324534066

# %%
print(gbr)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
gbr.fit(x_train,y_train)
pred=gbr.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# GradientBoostingRegressor()
#
#
# Mean Squared Error: 301956.724552554
# R-squared score: 0.06097586554474643

# %%
print(sv)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# SVR()
#
#
# Mean Squared Error: 339456.7229492819
# R-squared score: -0.05564151924355665

# %%
print(dtc)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=163)
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# DecisionTreeRegressor()
#
#
# Mean Squared Error: 676075.9453273999
# R-squared score: -1.1024589875513313

# %% [markdown]
# GradientBoostingRegressor model has the lowest MSE and the highest R-squared score among the evaluated models

# %% [markdown]
# ## CROSS VALIDATION SCORE

# %%
lr_scores = cross_val_score(lr, X, y, cv=5, scoring='r2')
rf_scores = cross_val_score(RFR, X, y, cv=5, scoring='r2')
gb_scores = cross_val_score(gbr, X, y, cv=5, scoring='r2')
svr_scores = cross_val_score(sv, X, y, cv=5, scoring='r2')
dt_scores = cross_val_score(dtc, X, y, cv=5, scoring='r2')

# Print the scores
print("Linear Regression scores:", lr_scores)
print("Random Forest scores:", rf_scores)
print("Gradient Boosting scores:", gb_scores)
print("SVR scores:", svr_scores)
print("Decision Tree scores:", dt_scores)
# Out:
# Linear Regression scores: [ 0.04775937 -0.03383762 -0.01407325 -0.3348995  -0.00064266]
# Random Forest scores: [-0.12190342 -0.14609089 -0.11442337 -0.44331343 -0.03315326]
# Gradient Boosting scores: [-0.0229713  -0.08340989 -0.04253565 -0.27968606 -0.01278059]
# SVR scores: [-0.00619904 -0.28383229 -0.13741392 -0.00681875 -0.07664631]
# Decision Tree scores: [-1.04148577 -1.18495155 -0.7217305  -2.22037894 -0.58731988]

# %% [markdown]
# The Linear Regression model has the highest R-squared score in the first fold (0.04775937), while the Decision Tree model has the lowest scores across all folds.

# %% [markdown]
# ## Hyper parameter tuning

# %% [markdown]
# Linear regression dont have any significant parameters for hyper parameter tuning

# %% [markdown]
# ## When Price Range is Target Variable

# %%
df_new=pd.merge(df1,df2)
df_new
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# #### Target Variable

# %%
df_new['Price range']
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %%
df_new['Price range'].nunique()
# Out:
# 4

# %%
df_new.shape
# Out:
# (9551, 22)

# %%
df_new.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df_new=df_new.dropna()

# %%
df_new.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.barplot(x="Price range", y='Aggregate rating', hue='Has Table booking', data=df_new)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %%
sns.barplot(x="Price range", y='Aggregate rating', hue='Is delivering now', data=df_new)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %%
sns.barplot(x="Price range", y='Aggregate rating', data=df_new)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %% [markdown]
# The 'Switch to order menu' service is not provided by any of the restaurants that have been reviewed in Zomato. But this interestingly shows the general trend of ratings provided by the users. The lower price restaurants in general have worser ratings compared to the pricier ones. There is essentially little difference in the ratings of price categories 1 and 2.
#
# Cuisines provided by the restaurants The above restaurants are a mix of single cusine and multi-cuisine restaurant. The rating of restaurants will be affected by the authenticity of the cuisine they are serving. I will first make a column of cusines that is served by the restaurants.

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
df_new.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
corr=df.corr()
corr
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.146270  -0.224362 -0.052626
# Country Code               0.146270      1.000000  -0.694629  0.018049
# Longitude                 -0.224362     -0.694629   1.000000  0.045415
# Latitude                  -0.052626      0.018049   0.045415  1.000000
# Average Cost for two      -0.001629      0.043717   0.045948 -0.111080
# Price range               -0.134528      0.245363  -0.080257 -0.166735
# Aggregate rating          -0.327160      0.281295  -0.114733  0.000197
# Votes                     -0.147434      0.154361  -0.084371 -0.022914
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001629    -0.134528         -0.327160
# Country Code                      0.043717     0.245363          0.281295
# Longitude                         0.045948    -0.080257         -0.114733
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,cmap='pink',annot=True)
plt.title("Correlation Heatmap")
plt.xlabel("Features")
plt.ylabel("Features")
plt.show()

# %% [markdown]
# ## Plotting Outliers

# %%
plt.figure(figsize=(12, 6))
df_new.plot(kind='box',subplots=True,layout=(2, 5))
plt.suptitle("Box Plots of DataFrame Columns")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separating Numerical and Categorical Columns

# %%
num_cols = df_new.select_dtypes(include=[np.number])

# %%
cat_cols = df_new.select_dtypes(exclude=[np.number])

# %%
num_cols
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 0                     1100            3               4.8    314
# 1                     1200            3               4.5    591
# 2                     4000            4               4.4    270
# ...

# %%
cat_cols
# Out:
#                Restaurant Name              City  \
# 0             Le Petit Souffle       Makati City
# 1             Izakaya Kikufuji       Makati City
# 2       Heat - Edsa Shangri-La  Mandaluyong City
# 3                         Ooma  Mandaluyong City
# 4                  Sambo Kojin  Mandaluyong City
# ...                        ...               ...
# 9546               Naml۱ Gurme         ��stanbul
# 9547              Ceviz A��ac۱         ��stanbul
# 9548                     Huqqa         ��stanbul
# 9549               A���k Kahve         ��stanbul
# 9550  Walter's Coffee Roastery         ��stanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...

# %% [markdown]
# ## Checkign Skewness

# %%
plt.figure(figsize=(10,8))
plotnumber=1
for i in num_cols.columns:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(num_cols[i],color='m')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separating Labels and Features

# %%
x1=num_cols.drop('Price range',axis=1)
y1=num_cols['Price range']

# %%
x1.shape
# Out:
# (9542, 7)

# %%
y1.shape
# Out:
# (9542,)

# %%
x1
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#       Average Cost for two  Aggregate rating  Votes
# 0                     1100               4.8    314
# 1                     1200               4.5    591
# 2                     4000               4.4    270
# 3                     1500               4.9    365
# ...

# %%
y1
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9542, dtype: int64

# %% [markdown]
# ## Removig Outliers

# %%
x1.shape
# Out:
# (9542, 7)

# %%
#removing the outliers by Z-Score method
from scipy.stats import zscore
z=np.abs(zscore(x1))
z
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Average Cost for two  \
# 0          0.310034      2.547817   1.377641  1.024849              0.006221
# 1          0.311552      2.547817   1.377315  1.025915              0.000020
# 2          0.312040      2.547817   1.378352  1.023399              0.173592
# 3          0.309935      2.547817   1.378344  1.023043              0.018581
# 4          0.310413      2.547817   1.378369  1.023122              0.018581
# ...             ...           ...        ...       ...                   ...
# 9546       0.355749      3.362717   0.856833  1.378286              0.069465
# 9547       0.356543      3.362717   0.855281  1.377110              0.067915
# 9548       0.355740      3.362717   0.855443  1.381285              0.063885
# 9549       0.355706      3.362717   0.855410  1.381482              0.066985
# 9550       0.354421      3.362717   0.855652  1.374833              0.071015
#
#       Aggregate rating     Votes
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  22,   23,   24, ..., 9539, 9540, 9541], dtype=int64), array([3, 3, 3, ..., 1, 1, 1], dtype=int64))

# %%
x1_new=x1[(z<3).all(axis=1)]
x1_new
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9432        6201972           166   51.526653  25.323261
# 9433        6201130           166   51.530127  25.350325
# 9434       18261203           166   51.512909  25.276180
# 9435        6201360           166   51.544576  25.273020
# 9436       18318801           166   51.546714  25.283011
#
#       Average Cost for two  Aggregate rating  Votes
# 0                     1100               4.8    314
# 1                     1200               4.5    591
# 2                     4000               4.4    270
# 3                     1500               4.9    365
# ...

# %%
977
# Out:
# 977

# %% [markdown]
# ## Removing Skewness

# %%
x1_new.skew()
# Out:
# Restaurant ID            0.117936
# Country Code            11.593933
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     3.718671
# Aggregate rating        -0.877262
# Votes                    3.653843
# dtype: float64

# %%
from scipy.stats import skew,boxcox
from scipy import stats
def skee(a):
    model=[np.sqrt(a),np.log(a),stats.boxcox(a)[0]]
    print('Original skewness was: ',a.skew())
    print('\n')
    for m in model:
        x=m
        print(skew(m))
        print('\n')

# %%
skee(x1_new['Country Code'])
# Out:
# Original skewness was:  11.593933482324417
#
#
# 11.548208765111612
#
#
# 11.53302807815674
#
#
# 11.530819180507189

# %%
x1_new['Country Code'] = np.cbrt(x1_new['Country Code'])

# %%
x1_new['Average Cost for two'] = np.cbrt(x1_new['Average Cost for two'])

# %%
x1_new['Votes'] = np.cbrt(x1_new['Votes'])

# %%
x1_new.skew()
# Out:
# Restaurant ID            0.117936
# Country Code            11.542592
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two     1.044058
# Aggregate rating        -0.877262
# Votes                    0.761689
# dtype: float64

# %%
x1_new['Average Cost for two'] = np.cbrt(x1_new['Average Cost for two'])

# %%
x1_new.skew()
# Out:
# Restaurant ID            0.117936
# Country Code            11.542592
# Longitude               -3.529965
# Latitude                -3.180873
# Average Cost for two    -1.062438
# Aggregate rating        -0.877262
# Votes                    0.761689
# dtype: float64

# %%
plt.figure(figsize=(12, 6))
x1_new.plot(kind='box',subplots=True,layout=(2, 5))
plt.suptitle("Box Plots of DataFrame Columns")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
plotnumber=1
for i in x1_new.columns:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(x1_new[i],color='m')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Encoding Categorical Column

# %%
from sklearn.preprocessing import LabelEncoder
cat_cols.select_dtypes(include=['object']).columns
label_encoders = {}
for col in cat_cols:
    le = LabelEncoder()
    cat_cols[col] = le.fit_transform(cat_cols[col])
    label_encoders[col] = le

# %%
cat_cols.dtypes
# Out:
# Restaurant Name         int32
# City                    int32
# Address                 int32
# Locality                int32
# Locality Verbose        int32
# Cuisines                int32
# Currency                int32
# Has Table booking       int32
# Has Online delivery     int32
# Is delivering now       int32
# Switch to order menu    int32
# Rating color            int32
# Rating text             int32
# Country                 int32
# dtype: object

# %%
cat_cols.shape
# Out:
# (9542, 14)

# %% [markdown]
# ## CONCATINATING FEATURE x_new and cat_col but before that reshaping

# %%
cat_cols=cat_cols[:len(x1_new)]

# %%
cat_cols.shape
# Out:
# (8565, 14)

# %%
X1=pd.merge(x1_new,cat_cols,left_index=True, right_index=True)

# %%
X1.shape
# Out:
# (7848, 21)

# %%
y1.shape
# Out:
# (9542,)

# %%
y1=y1[:len(X1)]

# %%
y1.shape
# Out:
# (7848,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X1=pd.DataFrame(scaler.fit_transform(X1),columns=X1.columns)
X1
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Average Cost for two  \
# 0         -0.257957     13.290441   2.721460 -1.767278              1.114962
# 1         -0.259443     13.290441   2.720693 -1.769002              1.234495
# 2         -0.259920     13.290441   2.723133 -1.764934              3.012767
# 3         -0.257860     13.290441   2.723112 -1.764359              1.546375
# 4         -0.258328     13.290441   2.723171 -1.764487              1.546375
# ...             ...           ...        ...       ...                   ...
# 7843      -0.927514     -0.073327   0.227704  0.291620              0.202911
# 7844       1.089769     -0.073327   0.227494  0.290212              0.843655
# 7845       1.086373     -0.073327   0.227730  0.291639             -0.539066
# 7846       1.090480     -0.073327   0.227494  0.290212             -0.193137
# 7847       1.091474     -0.073327   0.227876  0.291589             -0.048286
#
# ...

# %% [markdown]
# ## Checking Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(X1.values,i)
                    for i in range(len(X1.columns))]
vif['Features']=X1.columns

vif
# Out:
#     VIF values              Features
# 0     1.448064         Restaurant ID
# 1          inf          Country Code
# 2    10.844579             Longitude
# 3    11.239069              Latitude
# 4     1.813046  Average Cost for two
# 5     3.445794      Aggregate rating
# 6     4.009780                 Votes
# 7     1.007443       Restaurant Name
# 8     1.188495                  City
# 9     1.064963               Address
# 10  912.200152              Locality
# 11  912.560638      Locality Verbose
# 12    1.031038              Cuisines
# 13         inf              Currency
# 14    1.552061     Has Table booking
# 15    1.235968   Has Online delivery
# 16    1.015668     Is delivering now
# 17         NaN  Switch to order menu
# 18    1.251621          Rating color
# 19    1.652121           Rating text
# 20         inf               Country

# %% [markdown]
# Key Observations
#
# "Restaurant ID",'Price range','Aggregate rating','Votes','Restaurant Name','City','Address','Cuisines','Has Table booking','Has Online delivery','Is delivering now','Rating color','Rating text' has a VIF of min 1.44 to max 4.00, indicating a relatively low level of multicollinearity.
# "Country Code","Country" and "Currency" have VIF values of infinity (inf). This suggests perfect multicollinearity, indicating that these variables are redundant and should be removed from the model.
# "Longitude" and "Latitude" have VIF values of 10.86 and 11.28, respectively, indicating a moderate level of multicollinearity. Consider exploring whether these variables are necessary or if they can be transformed or combined.

# %%
data = X1.drop(['Country Code', 'Currency','Locality','Locality Verbose','Switch to order menu','Country', 'Longitude', 'Latitude'], axis=1,inplace =True)

# %%
vif = pd.DataFrame()
vif["Features"] = X1.columns
vif["VIF"] = [variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])]

print(vif)
# Out:
#                 Features       VIF
# 0          Restaurant ID  1.420145
# 1   Average Cost for two  1.790683
# 2       Aggregate rating  3.424414
# 3                  Votes  3.846088
# 4        Restaurant Name  1.006766
# 5                   City  1.066304
# 6                Address  1.045066
# 7               Cuisines  1.028645
# 8      Has Table booking  1.528585
# 9    Has Online delivery  1.192112
# 10     Is delivering now  1.014975
# 11          Rating color  1.228391
# 12           Rating text  1.625354

# %% [markdown]
# After dropping columns 'Country Code', 'Currency','Locality','Locality Verbose','Switch to order menu','Country', 'Longitude', 'Latitude' we can see no multicolinearlity present in the dataset

# %% [markdown]
# ## Splitting the data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X1, y1, test_size=0.30, random_state=43)

# %%
x_train.shape
# Out:
# (5493, 13)

# %%
y_train.shape
# Out:
# (5493,)

# %%
x_test.shape
# Out:
# (2355, 13)

# %%
y_test.shape
# Out:
# (2355,)

# %%
## Model Building

Finding the best random state
# Out:
#   File "C:\Users\23ady\AppData\Local\Temp\ipykernel_35200\3013751818.py", line 3
#     Finding the best random state
#             ^
# SyntaxError: invalid syntax

# %%
maxAccu=0
ln=LinearRegression()
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.3,random_state=i)
    mod=ln
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('the best accuracy is ',maxAccu,'on random state',maxRS)
# Out:
# the best accuracy is  0.06499539592967862 on random state 139

# %%
print(lr)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# LinearRegression()
#
#
# Mean Squared Error: 0.7274579027072021
# R-squared score: 0.07268596492198853

# %%
print(knn)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# KNeighborsRegressor()
#
#
# Mean Squared Error: 0.8644840764331212
# R-squared score: -0.10198571517965194

# %%
print(RFR)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# RandomForestRegressor()
#
#
# Mean Squared Error: 0.7200508280254777
# R-squared score: 0.08212800175418522

# %%
print(gbr)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
gbr.fit(x_train,y_train)
pred=gbr.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# GradientBoostingRegressor()
#
#
# Mean Squared Error: 0.7088217820299456
# R-squared score: 0.09644202860500717

# %%
print(sv)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# SVR()
#
#
# Mean Squared Error: 0.8117495459341303
# R-squared score: -0.0347633094803268

# %%
print(dtc)
print('\n')
x_train,x_test,y_train,y_test=train_test_split(X1,y1,test_size=0.20,random_state=139)
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print('Mean Squared Error:', mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print('R-squared score:',r2)
print('\n')
# Out:
# DecisionTreeRegressor()
#
#
# Mean Squared Error: 1.4675159235668789
# R-squared score: -0.8706898468759523

# %%
lr_scores = cross_val_score(lr, X1, y1, cv=5, scoring='r2')
rf_scores = cross_val_score(RFR, X1, y1, cv=5, scoring='r2')
gb_scores = cross_val_score(gbr, X1, y1, cv=5, scoring='r2')
svr_scores = cross_val_score(sv, X1, y1, cv=5, scoring='r2')
dt_scores = cross_val_score(dtc, X1, y1, cv=5, scoring='r2')

# Print the scores
print("Linear Regression scores:", lr_scores)
print("Random Forest scores:", rf_scores)
print("Gradient Boosting scores:", gb_scores)
print("SVR scores:", svr_scores)
print("Decision Tree scores:", dt_scores)
# Out:
# Linear Regression scores: [-0.38255456 -0.0960706  -0.01631448 -0.23451306 -0.01350419]
# Random Forest scores: [-0.19980662 -0.27900749 -0.10840792 -0.38869537 -0.0830045 ]
# Gradient Boosting scores: [-0.3238473  -0.20650419 -0.02203947 -0.23254103 -0.01831972]
# SVR scores: [-0.6693822  -0.50704155 -0.31199264 -0.25686473 -0.22537553]
# Decision Tree scores: [-1.03393035 -1.0780697  -0.97372722 -1.97243287 -1.07264864]

# %% [markdown]
# I will choose Linear Regresssion as my best Performing model and save the model

# %% [markdown]
# ## Saving The Model

# %%
#Since the Model without Outliers performing best! We will select that DataFrame.
#Saving the Model
import pickle
filename='zomato_res.pickle'
pickle.dump(lr,open(filename,'wb'))
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model.predict(x_test)
# Out:
# array([1.66083956, 1.6543346 , 1.72878113, ..., 2.12571167, 1.75126156,
#        1.95809182])
